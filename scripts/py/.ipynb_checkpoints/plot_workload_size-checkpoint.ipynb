# %% [markdown]
# # PyMongo Query
#
# db = "test"
# collection = "benchmarklogs"

# %%
from pymongo import MongoClient
client = MongoClient()

# %%
db = client['test']
collection = db['benchmarklogs']

# %%
import pprint

#pprint.pprint(collection.find_one())
for item in collection.find():
    pprint.pprint(item)
# Out:
# {'__v': 0,
#  '_id': ObjectId('5bc720ee7d339d27d7b277c7'),
#  'approach': 3,
#  'averageDelay': 8.612334000000008,
#  'benchmarkID': 0,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 503828,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4713124,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 143568,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 1000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 17.303,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 11, 45, 33, 220000),
#  'successfulTransactions': 1000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 57.79344622319829,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc721137d339d27d7b277c8'),
#  'approach': 3,
#  'averageDelay': 9.826377000000004,
#  'benchmarkID': 1,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 506289,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4713124,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 167010,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 1000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 22.135,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 11, 46, 4, 917000),
#  'successfulTransactions': 1000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 45.177320984865595,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc721347d339d27d7b277c9'),
#  'approach': 3,
#  'averageDelay': 17.15936799999998,
#  'benchmarkID': 2,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 508018,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4723897,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 170679,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 1000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 26.519,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 11, 46, 33, 808000),
#  'successfulTransactions': 1000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 37.70881254949282,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc721577d339d27d7b277ca'),
#  'approach': 3,
#  'averageDelay': 9.620719999999997,
#  'benchmarkID': 3,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 511994,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4713124,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 172704,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 1000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 16.48,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 11, 47, 18, 856000),
#  'successfulTransactions': 1000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 60.679611650485434,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc721707d339d27d7b277cb'),
#  'approach': 3,
#  'averageDelay': 12.474516000000008,
#  'benchmarkID': 4,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 514745,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4714767,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 173811,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 1000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 21.277,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 11, 47, 39, 536000),
#  'successfulTransactions': 1000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 46.999107016966676,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc721887d339d27d7b277cc'),
#  'approach': 3,
#  'averageDelay': 12.023535999999988,
#  'benchmarkID': 5,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 517259,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4713124,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 174692,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 1000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 20.352,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 11, 48, 4, 315000),
#  'successfulTransactions': 1000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 49.13522012578616,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc721a27d339d27d7b277cd'),
#  'approach': 3,
#  'averageDelay': 14.426759999999994,
#  'benchmarkID': 6,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 520799,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4709680,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 177426,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 1000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 21.266,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 11, 48, 28, 922000),
#  'successfulTransactions': 1000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 47.02341766199568,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc721b37d339d27d7b277ce'),
#  'approach': 3,
#  'averageDelay': 7.6515719999999945,
#  'benchmarkID': 7,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 522833,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4713610,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 166340,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 1000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 13.007,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 11, 48, 54, 430000),
#  'successfulTransactions': 1000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 76.88167909587146,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc721c37d339d27d7b277cf'),
#  'approach': 3,
#  'averageDelay': 5.653003999999997,
#  'benchmarkID': 8,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 524875,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4723275,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 165751,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 1000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 11.254,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 11, 49, 11, 957000),
#  'successfulTransactions': 1000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 88.85729518393461,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc721e67d339d27d7b277d0'),
#  'approach': 3,
#  'averageDelay': 14.157008000000005,
#  'benchmarkID': 9,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 527696,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4719044,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 176818,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 1000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 22.292,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 11, 49, 35, 675000),
#  'successfulTransactions': 1000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 44.85914229319935,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc7226c7d339d27d7b277d2'),
#  'approach': 3,
#  'averageDelay': 22.766581000000016,
#  'benchmarkID': 11,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 503828,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4728479,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 149233,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 2000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 40.813,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 11, 51, 31, 902000),
#  'successfulTransactions': 2000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 49.00399382549678,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc722cf7d339d27d7b277d3'),
#  'approach': 3,
#  'averageDelay': 35.724052499999964,
#  'benchmarkID': 12,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 508514,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4728479,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 179884,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 2000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 71.653,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 11, 52, 39, 812000),
#  'successfulTransactions': 2000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 27.91229955479882,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc7230a7d339d27d7b277d4'),
#  'approach': 3,
#  'averageDelay': 27.181136000000006,
#  'benchmarkID': 13,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 512243,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4743248,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 180932,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 2000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 52.16,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 11, 53, 58, 298000),
#  'successfulTransactions': 2000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 38.34355828220859,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc7233b7d339d27d7b277d5'),
#  'approach': 3,
#  'averageDelay': 18.028391499999998,
#  'benchmarkID': 14,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 516755,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4753034,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 180751,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 2000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 32.608,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 11, 55, 6, 525000),
#  'successfulTransactions': 2000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 61.33464180569186,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc7237b7d339d27d7b277d6'),
#  'approach': 3,
#  'averageDelay': 17.2584505,
#  'benchmarkID': 15,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 521815,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4752851,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 181488,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 2000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 37.715,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 11, 56, 5, 550000),
#  'successfulTransactions': 2000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 53.02929868752485,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc723ad7d339d27d7b277d7'),
#  'approach': 3,
#  'averageDelay': 22.691392500000017,
#  'benchmarkID': 16,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 525899,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4758405,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 173280,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 2000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 37.517,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 11, 56, 56, 49000),
#  'successfulTransactions': 2000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 53.309166511181594,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc723e77d339d27d7b277d8'),
#  'approach': 3,
#  'averageDelay': 19.845458500000007,
#  'benchmarkID': 17,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 530790,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4758658,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 174549,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 2000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 33.87,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 11, 57, 57, 959000),
#  'successfulTransactions': 2000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 59.0493061706525,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc724317d339d27d7b277d9'),
#  'approach': 3,
#  'averageDelay': 16.447891000000013,
#  'benchmarkID': 18,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 539130,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4728479,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 181466,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 2000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 31.928,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 11, 59, 13, 612000),
#  'successfulTransactions': 2000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 62.64094211976948,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc724707d339d27d7b277da'),
#  'approach': 3,
#  'averageDelay': 14.287381499999988,
#  'benchmarkID': 19,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 547335,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4728479,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 173780,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 2000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 25.667,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 12, 0, 22, 382000),
#  'successfulTransactions': 2000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 77.92106596018233,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc724bf7d339d27d7b277db'),
#  'approach': 3,
#  'averageDelay': 16.287307500000004,
#  'benchmarkID': 20,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 555124,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4728479,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 181397,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 2000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 33.261,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 12, 1, 34, 229000),
#  'successfulTransactions': 2000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 60.13048314843209,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc72e070b695e2ab63a8fde'),
#  'approach': 3,
#  'averageDelay': 29.62525333333337,
#  'benchmarkID': 21,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 508266,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4743462,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 158925,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 3000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 56.02,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 12, 40, 47, 770000),
#  'successfulTransactions': 3000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 53.5523027490182,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc72e660b695e2ab63a8fdf'),
#  'approach': 3,
#  'averageDelay': 30.866616666666644,
#  'benchmarkID': 22,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 515247,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4743917,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 173912,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 3000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 71.359,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 12, 42, 7, 459000),
#  'successfulTransactions': 3000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 42.040947883238275,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc72edf0b695e2ab63a8fe0'),
#  'approach': 3,
#  'averageDelay': 21.254368666666707,
#  'benchmarkID': 23,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 525387,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4743917,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 173809,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 3000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 49.811,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 12, 44, 29, 769000),
#  'successfulTransactions': 3000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 60.2276605569051,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc72f300b695e2ab63a8fe1'),
#  'approach': 3,
#  'averageDelay': 24.370522999999988,
#  'benchmarkID': 24,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 534944,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4743917,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 159600,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 3000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 51.673,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 12, 45, 48, 435000),
#  'successfulTransactions': 3000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 58.05739941555551,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc72f780b695e2ab63a8fe2'),
#  'approach': 3,
#  'averageDelay': 35.657290333333435,
#  'benchmarkID': 25,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 541764,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4761572,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 153585,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 3000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 62.082,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 12, 46, 50, 278000),
#  'successfulTransactions': 3000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 48.32318546438581,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc72fd90b695e2ab63a8fe3'),
#  'approach': 3,
#  'averageDelay': 49.31975666666669,
#  'benchmarkID': 26,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 547869,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4787333,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 165312,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 3000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 92.606,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 12, 47, 56, 936000),
#  'successfulTransactions': 3000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 32.39530915923375,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc7302e0b695e2ab63a8fe4'),
#  'approach': 3,
#  'averageDelay': 35.824577333333366,
#  'benchmarkID': 27,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 558380,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4743782,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 164350,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 3000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 60.994,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 12, 49, 53, 674000),
#  'successfulTransactions': 3000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 49.185165754008594,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc730a30b695e2ab63a8fe5'),
#  'approach': 3,
#  'averageDelay': 58.63390466666668,
#  'benchmarkID': 28,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 566326,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4743917,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 163425,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 3000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 92.568,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 12, 51, 18, 697000),
#  'successfulTransactions': 3000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 32.40860772621208,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc730e00b695e2ab63a8fe6'),
#  'approach': 3,
#  'averageDelay': 21.179404666666702,
#  'benchmarkID': 29,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 573546,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4763621,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 157010,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 3000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 46.214,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 12, 53, 5, 761000),
#  'successfulTransactions': 3000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 64.91539360366988,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc7315e0b695e2ab63a8fe7'),
#  'approach': 3,
#  'averageDelay': 33.997490999999975,
#  'benchmarkID': 30,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 582561,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4739259,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 169881,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 3000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 72.926,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 12, 54, 45, 529000),
#  'successfulTransactions': 3000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 41.137591531141155,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc731e60b695e2ab63a8fe8'),
#  'approach': 3,
#  'averageDelay': 16.67425539568345,
#  'benchmarkID': 31,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 507771,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4758618,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 140569,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 4000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 75.903,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 12, 56, 57, 978000),
#  'successfulTransactions': 834,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 10.987707995731393,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc732610b695e2ab63a8fe9'),
#  'approach': 3,
#  'averageDelay': 39.119570824524324,
#  'benchmarkID': 32,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 514996,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4793204,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 165860,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 4000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 90.936,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 12, 58, 46, 294000),
#  'successfulTransactions': 946,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 10.402920735462303,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc733230b695e2ab63a8fea'),
#  'approach': 3,
#  'averageDelay': 45.6850082499999,
#  'benchmarkID': 33,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 533903,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4759387,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 170266,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 4000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 87.556,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 13, 2, 4, 291000),
#  'successfulTransactions': 4000,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 45.68504728402394,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc7338b0b695e2ab63a8feb'),
#  'approach': 3,
#  'averageDelay': 40.4600453038674,
#  'benchmarkID': 34,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 543085,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4779191,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 170203,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 4000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 88.13,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 13, 3, 47, 145000),
#  'successfulTransactions': 905,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 10.268920912288666,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc733e80b695e2ab63a8fec'),
#  'approach': 3,
#  'averageDelay': 23.176555820895484,
#  'benchmarkID': 35,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 550277,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4825535,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 174322,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 4000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 84.38,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 13, 5, 23, 901000),
#  'successfulTransactions': 1675,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 19.85067551552501,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc734530b695e2ab63a8fed'),
#  'approach': 3,
#  'averageDelay': 40.041250602409654,
#  'benchmarkID': 36,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 557564,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4865326,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 178698,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 4000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 97.888,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 13, 6, 57, 1000),
#  'successfulTransactions': 830,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 8.479078130107878,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc734bf0b695e2ab63a8fee'),
#  'approach': 3,
#  'averageDelay': 36.31583096590919,
#  'benchmarkID': 37,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 565223,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4905148,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 177950,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 4000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 102.945,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 13, 8, 40, 788000),
#  'successfulTransactions': 704,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 6.8386031375977465,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc7352d0b695e2ab63a8fef'),
#  'approach': 3,
#  'averageDelay': 40.470730569948216,
#  'benchmarkID': 38,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 573546,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4940469,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 180429,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 4000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 98.416,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 13, 10, 35, 34000),
#  'successfulTransactions': 772,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 7.844252966997236,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc735ac0b695e2ab63a8ff0'),
#  'approach': 3,
#  'averageDelay': 47.69712970711299,
#  'benchmarkID': 39,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 579728,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4983792,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 173887,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 4000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 117.587,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 13, 12, 22, 699000),
#  'successfulTransactions': 478,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 4.06507522090027,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc736240b695e2ab63a8ff1'),
#  'approach': 3,
#  'averageDelay': 62.66272641509432,
#  'benchmarkID': 40,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 587120,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 5012804,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 162469,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 4000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 107.558,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 13, 14, 32, 694000),
#  'successfulTransactions': 212,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 1.9710295840383791,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc736b80b695e2ab63a8ff2'),
#  'approach': 3,
#  'averageDelay': 47.92371618743337,
#  'benchmarkID': 41,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 509506,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4774935,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 136069,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 5000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 104.335,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 13, 17, 3, 948000),
#  'successfulTransactions': 1878,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 17.999712464657115,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc737580b695e2ab63a8ff3'),
#  'approach': 3,
#  'averageDelay': 50.48896963696376,
#  'benchmarkID': 42,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 517259,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4820637,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 167649,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 5000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 136.357,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 13, 19, 11, 942000),
#  'successfulTransactions': 1515,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 11.110540712981365,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc737b70b695e2ab63a8ff4'),
#  'approach': 3,
#  'averageDelay': 34.5768153380424,
#  'benchmarkID': 43,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 526411,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4885752,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 151698,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 5000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 89.962,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 13, 21, 33, 560000),
#  'successfulTransactions': 1982,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 22.03152442142238,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc7385c0b695e2ab63a8ff5'),
#  'approach': 3,
#  'averageDelay': 61.77071113831102,
#  'benchmarkID': 44,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 540972,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4842056,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 156001,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 5000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 115.351,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 13, 23, 53, 257000),
#  'successfulTransactions': 1634,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 14.165460204072787,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc738ee0b695e2ab63a8ff6'),
#  'approach': 3,
#  'averageDelay': 52.28025229638698,
#  'benchmarkID': 45,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 550545,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4877944,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 165722,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 5000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 133.154,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 13, 26, 1, 143000),
#  'successfulTransactions': 1633,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 12.263995073373687,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc7396f0b695e2ab63a8ff7'),
#  'approach': 3,
#  'averageDelay': 76.16237676056323,
#  'benchmarkID': 46,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 558924,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4949889,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 160844,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 5000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 122.746,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 13, 28, 20, 748000),
#  'successfulTransactions': 1420,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 11.568605086927477,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc73a090b695e2ab63a8ff8'),
#  'approach': 3,
#  'averageDelay': 65.82741214574897,
#  'benchmarkID': 47,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 567707,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 4997863,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 164203,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 5000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 131.654,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 13, 30, 45, 468000),
#  'successfulTransactions': 1235,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 9.380649277652028,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc73a8f0b695e2ab63a8ff9'),
#  'approach': 3,
#  'averageDelay': 61.999067114093954,
#  'benchmarkID': 48,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 578036,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 5026074,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 153307,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 5000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 107.381,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 13, 33, 23, 878000),
#  'successfulTransactions': 596,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 5.550330132891293,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc73b0e0b695e2ab63a8ffa'),
#  'approach': 3,
#  'averageDelay': 53.56717686692867,
#  'benchmarkID': 49,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 587979,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 5062073,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 162680,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 5000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 111.976,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 13, 35, 26, 698000),
#  'successfulTransactions': 1781,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 15.905193970136457,
#  'usedGenesisJson': 'genesis_pow_default.json'}
# {'__v': 0,
#  '_id': ObjectId('5bc73b8a0b695e2ab63a8ffb'),
#  'approach': 3,
#  'averageDelay': 47.4907448512586,
#  'benchmarkID': 50,
#  'clique': False,
#  'clique_period': 0,
#  'difficulty': 596930,
#  'difficulty_genesis_dec': 524288,
#  'difficulty_genesis_hex': '0x80000',
#  'ethash': True,
#  'gasLimit': 5124628,
#  'gasLimit_genesis_dec': 4700000,
#  'gasLimit_genesis_hex': '0x47b760',
#  'hashRate': 163284,
#  'instanceType': 'c5.xlarge',
#  'ip': '18.184.180.17',
#  'maxRuntime': 600000,
#  'maxRuntimeReached': False,
#  'maxTransactions': 5000,
#  'maxTransactionsReached': True,
#  'miners': 1,
#  'mining': True,
#  'nodes': 1,
#  'peerCount': 0,
#  'runtime': 118.635,
#  'scenario': 'account',
#  'startTime': datetime.datetime(2018, 10, 17, 13, 37, 23, 968000),
#  'successfulTransactions': 874,
#  'targetGasLimit': 4700000,
#  'txPerSecond': 7.3671344881358785,
#  'usedGenesisJson': 'genesis_pow_default.json'}

# %% [markdown]
# # PyMongo Query ->Pandas DataFrame

# %%
import pandas as pd

query={"$and":[ {"$or":[ {"maxTransactions":1000}, {"maxTransactions":2000},{"maxTransactions":3000},{"maxTransactions":4000},{"maxTransactions":5000}]}
, {"usedGenesisJson":'genesis_pow_default.json'}, {"instanceType":'c5.xlarge'}]}

# Make a query to the specific DB and Collection
cursor = collection.find(query)

# Expand the cursor and construct the DataFrame
df =  pd.DataFrame(list(cursor))

#df.head(20)

data = df[['txPerSecond','maxTransactions']]
txPerSecond = df['txPerSecond']
maxTransactions =df['maxTransactions']
print(data)
# Out:
#     txPerSecond  maxTransactions
# 0     57.793446             1000
# 1     45.177321             1000
# 2     37.708813             1000
# 3     60.679612             1000
# 4     46.999107             1000
# 5     49.135220             1000
# 6     47.023418             1000
# 7     76.881679             1000
# 8     88.857295             1000
# 9     44.859142             1000
# 10    49.003994             2000
# 11    27.912300             2000
# 12    38.343558             2000
# 13    61.334642             2000
# 14    53.029299             2000
# 15    53.309167             2000
# 16    59.049306             2000
# 17    62.640942             2000
# 18    77.921066             2000
# 19    60.130483             2000
# 20    53.552303             3000
# 21    42.040948             3000
# 22    60.227661             3000
# 23    58.057399             3000
# 24    48.323185             3000
# 25    32.395309             3000
# 26    49.185166             3000
# 27    32.408608             3000
# 28    64.915394             3000
# 29    41.137592             3000
# 30    10.987708             4000
# 31    10.402921             4000
# 32    45.685047             4000
# 33    10.268921             4000
# 34    19.850676             4000
# 35     8.479078             4000
# 36     6.838603             4000
# 37     7.844253             4000
# 38     4.065075             4000
# 39     1.971030             4000
# 40    17.999712             5000
# 41    11.110541             5000
# 42    22.031524             5000
# 43    14.165460             5000
# 44    12.263995             5000
# 45    11.568605             5000
# 46     9.380649             5000
# 47     5.550330             5000
# 48    15.905194             5000
# 49     7.367134             5000

# %% [markdown]
# # Pandas DataFrame -> Plot

# %%
import matplotlib.pyplot as plt

title="Effect of Workload Size on Throughput"
xlabel="Workload Size (Transactions)"
ylabel="Transactions Per Second (TPS)"


plt.scatter(maxTransactions,txPerSecond)
plt.title(title)
plt.ylabel(ylabel)
plt.xlabel(xlabel)
plt.savefig("workload_size_throughput_scatter.svg", format="svg")
plt.show()

# %%
fig = plt.figure(1, figsize=(9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

# Create the boxplot

## combine these different collections into a list    
data_to_plot = [data.loc[df['maxTransactions'] == 1000].iloc[:,0],
                data.loc[df['maxTransactions'] == 2000].iloc[:,0],
                data.loc[df['maxTransactions'] == 3000].iloc[:,0],
                data.loc[df['maxTransactions'] == 4000].iloc[:,0],
                data.loc[df['maxTransactions'] == 5000].iloc[:,0]]

bp = ax.boxplot(data_to_plot,labels=list(["1000","2000","3000","4000","5000"]))
fig.savefig("workload_size_throughput_boxplot.svg", format="svg")

# %%
avg1000=data.loc[df['maxTransactions'] == 1000].iloc[:,0].mean()
avg2000=data.loc[df['maxTransactions'] == 2000].iloc[:,0].mean()
avg3000=data.loc[df['maxTransactions'] == 3000].iloc[:,0].mean()
avg4000=data.loc[df['maxTransactions'] == 4000].iloc[:,0].mean()
avg5000=data.loc[df['maxTransactions'] == 5000].iloc[:,0].mean()

print(avg1000)
print(avg2000)
print(avg3000)
print(avg4000)
print(avg5000)

plt.plot([1000,2000,3000,4000,5000],[avg1000,avg2000,avg3000,avg4000,avg5000])
plt.title(title)
plt.ylabel("Average Transactions Per Second (TPS)")
plt.xlabel(xlabel)
plt.savefig("workload_size_throughput_lines_average.svg", format="svg")
plt.show()
# Out:
# 55.51150527857961
# 54.26747560659389
# 48.22435638433684
# 12.63933114826728
# 12.734314583225046

# %%
# Out:
# 55.51150527857961
# 54.26747560659389
# 48.22435638433684
# 12.63933114826728
# 12.734314583225046
