# %% [markdown]
# # PyMongo Query
#
# db = "test"
# collection = "benchmarklogs"

# %%
from pymongo import MongoClient
client = MongoClient()

db = client['test']
collection = db['benchmarklogs']

# %% [markdown]
# # PyMongo Query ->Pandas DataFrame

# %%
import numpy as np
import pandas as pd

query = {"$and":[ {"$or":[{"nodes":1}, {"nodes":5}, {"nodes":10}, {"nodes":15}, {"nodes":20}]}, 
        {"usedGenesisJson":"genesis_pow_default.json"}, {"instanceType":"t2.xlarge"}, {"maxTransactions": 1000}, {"successfulTransactions":1000}, {"scenario":"account"}]}

# query = {}

# Make a query to the specific DB and Collection
cursor = collection.find(query)

# Expand the cursor and construct the DataFrame
df = pd.DataFrame(list(cursor))

#display(df.head(200))

# %% [markdown]
# # Pandas DataFrame -> Plot
# ## Throughput

# %%
import matplotlib.pyplot as plt

data_tps_instanceType = df[['txPerSecond','nodes']]

title = "Throughput against Network Size (PoW)"
xlabel = "Network Size"
ylabel = "Transactions Per Second (TPS)"
ylabelAverage = "Average Transactions Per Second (TPS)"

avg1_tps = data_tps_instanceType.loc[df['nodes'] == 1].iloc[:,0].mean()
avg2_tps = data_tps_instanceType.loc[df['nodes'] == 5].iloc[:,0].mean()
avg3_tps = data_tps_instanceType.loc[df['nodes'] == 10].iloc[:,0].mean()
avg4_tps = data_tps_instanceType.loc[df['nodes'] == 15].iloc[:,0].mean()
avg5_tps = data_tps_instanceType.loc[df['nodes'] == 20].iloc[:,0].mean()

# %%
color_latency="#ff7f0e"
color_tps="#1f77b4"
objects = ('1', '5', '10', '15', '20')

fig = plt.figure(1, figsize=(9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

# Create the boxplot

## combine these different collections into a list    
data_to_plot = [data_tps_instanceType.loc[df['nodes'] == 1].iloc[:,0],
                data_tps_instanceType.loc[df['nodes'] == 5].iloc[:,0],
                data_tps_instanceType.loc[df['nodes'] == 10].iloc[:,0],
                data_tps_instanceType.loc[df['nodes'] == 15].iloc[:,0],
                data_tps_instanceType.loc[df['nodes'] == 20].iloc[:,0]]

bp = ax.boxplot(data_to_plot,labels=objects, patch_artist=True)

## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set(color=color_tps, linewidth=2)
    # change fill color
    box.set(facecolor="w")
    
## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color="k", linewidth=2) 
    
fig.savefig("network_size_pow_throughput_boxplot.svg", format="svg")

# %%
y_pos = np.arange(len(objects))
performance = [avg1_tps,avg2_tps,avg3_tps,avg4_tps,avg5_tps]
 
plt.bar(y_pos, performance, align='center', alpha=0.5,color=color_tps)
plt.xticks(y_pos, objects)
plt.ylabel(ylabelAverage)
plt.title(title)
plt.savefig("network_size_pow_throughput_barchart.svg", format="svg")
plt.show()

# %% [markdown]
# ## Latency

# %%
data_latency_instanceType = df[['averageDelay','nodes']]

title = "Latency against Network Size (PoW)"
xlabel = "Network Size"
ylabel = "Transaction Latency [seconds]"
ylabelAverage = "Average Transaction Latency [seconds]"

avg1_latency = data_latency_instanceType.loc[df['nodes'] == 1].iloc[:,0].mean()
avg2_latency = data_latency_instanceType.loc[df['nodes'] == 5].iloc[:,0].mean()
avg3_latency = data_latency_instanceType.loc[df['nodes'] == 10].iloc[:,0].mean()
avg4_latency = data_latency_instanceType.loc[df['nodes'] == 15].iloc[:,0].mean()
avg5_latency = data_latency_instanceType.loc[df['nodes'] == 20].iloc[:,0].mean()

# %%
fig = plt.figure(1, figsize=(9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

# Create the boxplot

## combine these different collections into a list    
data_to_plot = [data_latency_instanceType.loc[df['nodes'] == 1].iloc[:,0],
                data_latency_instanceType.loc[df['nodes'] == 5].iloc[:,0],
                data_latency_instanceType.loc[df['nodes'] == 10].iloc[:,0],
                data_latency_instanceType.loc[df['nodes'] == 15].iloc[:,0],
                data_latency_instanceType.loc[df['nodes'] == 20].iloc[:,0]]

bp = ax.boxplot(data_to_plot,labels=objects, patch_artist=True)

## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set( color=color_latency, linewidth=2)
    # change fill color
    box.set( facecolor = 'w' )
    
## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color="k", linewidth=2) 
    
fig.savefig("network_size_pow_latency_boxplot.svg", format="svg")

# %%
y_pos = np.arange(len(objects))
performance = [avg1_latency,avg2_latency,avg3_latency,avg4_latency,avg5_latency]
 
plt.bar(y_pos, performance, align='center', alpha=0.5, color=color_latency)
plt.xticks(y_pos, objects)
plt.ylabel(ylabelAverage)
plt.title(title)
plt.savefig("network_size_pow_latency_barchart.svg", format="svg")
plt.show()

# %% [markdown]
# ## Throughput and Latency Combined

# %%
means_tps = [avg1_tps, avg2_tps, avg3_tps, avg4_tps, avg5_tps]
means_latency = [avg1_latency, avg2_latency, avg3_latency, avg4_latency, avg5_latency]

df = pd.DataFrame({'Average Throughput [TPS]':means_tps, 'Average Latency [seconds]':means_latency})
print(df)

fig = plt.figure()
ax = df.plot( kind= 'bar' , color=tuple([color_tps, color_latency]), secondary_y= ['Average Latency [seconds]'] ,mark_right=True,ylim=(0, 200), use_index=False)
ax.set_xticklabels(objects)
ax.set_title('Throughput and Latency against Network Size (PoW)')
ax.figure.savefig("network_size_pow_combined_barchart.svg", format="svg",bbox_inches='tight')
plt.show()
# Out:
#    Average Throughput [TPS]  Average Latency [seconds]
# 0                 40.487407                  15.826147
# 1                 79.593987                   7.578683
# 2                 68.882772                  10.094840
# 3                 59.245746                  11.494136
# 4                 53.025271                  11.335584
