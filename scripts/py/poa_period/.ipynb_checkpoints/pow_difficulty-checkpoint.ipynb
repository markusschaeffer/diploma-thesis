# %% [markdown]
# # PyMongo Query
#
# db = "test"
# collection = "benchmarklogs"

# %%
from pymongo import MongoClient
client = MongoClient()

# %%
db = client['test']
collection = db['benchmarklogs']

# %%
import pprint

#pprint.pprint(collection.find_one())
#for item in collection.find():
#    pprint.pprint(item)

# %% [markdown]
# # PyMongo Query ->Pandas DataFrame

# %%
import pandas as pd

query = {"$and":[ {"$or":[ {"usedGenesisJson":"genesis_pow_difficulty_1.json"},{"usedGenesisJson":"genesis_pow_difficulty_05.json"},{"usedGenesisJson":"genesis_pow_difficulty_025.json"},{"usedGenesisJson":"genesis_pow_difficulty_2.json"},{"usedGenesisJson":"genesis_pow_difficulty_4.json"} ]}, 
        {"maxTransactions": 1000}, {"instanceType":'c5.xlarge'}, {"nodes":5}]}

# query = {}

# Make a query to the specific DB and Collection
cursor = collection.find(query)

# Expand the cursor and construct the DataFrame
df = pd.DataFrame(list(cursor))

#display(df.head(200))

# %% [markdown]
# # Pandas DataFrame -> Plot
# ## Throughput

# %%
import matplotlib.pyplot as plt

data_tps = df[['txPerSecond','usedGenesisJson']]
#print(data_tps)

title = "Effect of Mining Difficulty on Throughput in PoW"
xlabel = "Mining Difficulty Factor"
ylabel = "Transactions Per Second (TPS)"

# %%
fig = plt.figure(1, figsize=(9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

# Create the boxplot

## combine these different collections into a list    
data_to_plot = [data_tps.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_025.json"].iloc[:,0],
                data_tps.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_05.json"].iloc[:,0],
                data_tps.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_1.json"].iloc[:,0],
                data_tps.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_2.json"].iloc[:,0],
                data_tps.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_4.json"].iloc[:,0]]

bp = ax.boxplot(data_to_plot,labels=list(["Factor 0.25","Factor 0.5","Factor 1 (default)","Factor 2","Factor 4"]))
fig.savefig("difficulty_pow_throughput_boxplot.svg", format="svg")

# %%
avg025 = data_tps.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_025.json"].iloc[:,0].mean()
avg05 = data_tps.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_05.json"].iloc[:,0].mean()
avg1 = data_tps.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_1.json"].iloc[:,0].mean()
avg2 = data_tps.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_2.json"].iloc[:,0].mean()
avg4 = data_tps.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_4.json"].iloc[:,0].mean()

print(avg025)
print(avg05)
print(avg1)
print(avg2)
print(avg4)

plt.plot([0.25,0.5,1,2,4], [avg025,avg05,avg1,avg2,avg4], marker='o')
plt.title(title)
plt.ylabel("Average Transactions Per Second (TPS)")
plt.xlabel(xlabel)
plt.savefig("difficulty_pow_throughput_lines_average.svg", format="svg")
plt.show()
# Out:
# 78.77319585291059
# 78.81105658507636
# 79.29955709122235
# 69.44021429309878
# 45.23862084477706

# %% [markdown]
# ## Latency

# %%
data_latency = df[['averageDelay','usedGenesisJson']]
#print(data_latency)

title = "Effect of Mining Difficulty on Latency in PoW"
xlabel = "Mining Difficulty Factor"
ylabel = "Transaction Latency [seconds]"

# %%
fig = plt.figure(1, figsize=(9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

ax.set_title(title)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

# Create the boxplot

## combine these different collections into a list    
data_to_plot = [data_latency.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_025.json"].iloc[:,0],
                data_latency.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_05.json"].iloc[:,0],
                data_latency.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_1.json"].iloc[:,0],
                data_latency.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_2.json"].iloc[:,0],
                data_latency.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_4.json"].iloc[:,0]]

bp = ax.boxplot(data_to_plot,labels=list(["Factor 0.25","Factor 0.5","Factor 1 (default)","Factor 2","Factor 4"]))
fig.savefig("difficulty_pow_latency_boxplot.svg", format="svg")

# %%
avg025 = data_latency.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_025.json"].iloc[:,0].mean()
avg05 = data_latency.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_05.json"].iloc[:,0].mean()
avg1 = data_latency.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_1.json"].iloc[:,0].mean()
avg2 = data_latency.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_2.json"].iloc[:,0].mean()
avg4 = data_latency.loc[df['usedGenesisJson'] == "genesis_pow_difficulty_4.json"].iloc[:,0].mean()

print(avg025)
print(avg05)
print(avg1)
print(avg2)
print(avg4)

plt.plot([0.25,0.5,1,2,4], [avg025,avg05,avg1,avg2,avg4], marker='o')
plt.title(title)
plt.ylabel("Average Transaction Latency [seconds]")
plt.xlabel(xlabel)
plt.savefig("difficulty_pow_latency_lines_average.svg", format="svg")
plt.show()
# Out:
# 7.284053950000002
# 7.624358650000002
# 7.52260505
# 8.666864699999996
# 13.36491
